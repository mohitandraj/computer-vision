# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
img1= plt.imread('lenna.png')
img2= cv2.imread('lenna.png')

# %%
### Pixel Operations

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
img1
# Out:
# array([[[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        ...,
#
#        [[0.32941177, 0.07058824, 0.23529412],
# ...

# %%
img2
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
# ...

# %%
cv2.imshow('My Image',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img3 = img2/255

# %%
img3
# Out:
# array([[[0.49019608, 0.5372549 , 0.88627451],
#         [0.49019608, 0.5372549 , 0.88627451],
#         [0.52156863, 0.5372549 , 0.8745098 ],
#         ...,
#         [0.47843137, 0.58039216, 0.90196078],
#         [0.43137255, 0.50980392, 0.86666667],
#         [0.35294118, 0.38823529, 0.78431373]],
#
#        [[0.49019608, 0.5372549 , 0.88627451],
#         [0.49019608, 0.5372549 , 0.88627451],
#         [0.52156863, 0.5372549 , 0.8745098 ],
#         ...,
#         [0.47843137, 0.58039216, 0.90196078],
#         [0.43137255, 0.50980392, 0.86666667],
#         [0.35294118, 0.38823529, 0.78431373]],
#
#        [[0.49019608, 0.5372549 , 0.88627451],
#         [0.49019608, 0.5372549 , 0.88627451],
#         [0.52156863, 0.5372549 , 0.8745098 ],
#         ...,
#         [0.47843137, 0.58039216, 0.90196078],
#         [0.43137255, 0.50980392, 0.86666667],
#         [0.35294118, 0.38823529, 0.78431373]],
#
#        ...,
#
#        [[0.23529412, 0.07058824, 0.32941176],
# ...

# %%
cv2.imshow('Normalized Image',img3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
pix1 = img1[100,100]

# %%
pix1
# Out:
# array([0.69803923, 0.26666668, 0.30588236], dtype=float32)

# %%
pix1.shape
# Out:
# (3,)

# %%
pix1=pix1.reshape(1,1,3)

# %%
plt.imshow(pix1)

# %%
zero= np.array([[0,0,0]])

# %%
zero.shape
# Out:
# (1, 3)

# %%
img1[100,100]= zero

# %%
plt.imshow(img1)

# %%
img1[128]=0

# %%
plt.imshow(img1)

# %%
img1[256]=0

# %%
plt.imshow(img1)

# %%
for row in range(img1.shape[0]):
    for col in range(img1.shape[1]):
        if row == col:
            img1[row,col]=zero

# %%
plt.imshow(img1)

# %%
for row in range(img1.shape[0]):
    for col in range(img1.shape[1]):
        if row == col:
            img1[row,col]=0
        if row + col == img1.shape[1]:
            img1[row,col]= 0

# %%
plt.imshow(img1)

# %%
### PIXEL MANIPULATION USING PIL

# %%
img4= Image.open('lenna.png')

# %%
img4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
pix2= img4.getpixel((100,100))

# %%
pix2= np.reshape(pix2,(1,1,3))
plt.imshow(pix2)

# %%
img4.putpixel((100,100),(255,255,255))

# %%
img4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %% [markdown]
# <h4>Video Operations</h4>

# %%
vid=cv2.VideoCapture('nature.mp4')

# %%
vid
# Out:
# < cv2.VideoCapture 000001B214A38530>

# %%
ret, frame = vid.read()

# %%
ret
# Out:
# True

# %%
frame
# Out:
# array([[[ 48,  49,  44],
#         [ 41,  42,  37],
#         [ 38,  39,  34],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 43,  44,  39],
#         [ 37,  38,  33],
#         [ 32,  33,  28],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 40,  41,  36],
#         [ 36,  37,  32],
#         [ 30,  31,  26],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 32,  31,  25],
#         [ 26,  25,  19],
#         [ 26,  25,  19],
#         ...,
#         [ 27,  23,  19],
#         [ 27,  23,  19],
#         [ 28,  24,  20]],
#
#        [[ 32,  31,  25],
#         [ 26,  25,  19],
#         [ 26,  25,  19],
#         ...,
#         [ 27,  23,  19],
#         [ 27,  23,  19],
#         [ 28,  24,  20]],
#
#        [[ 32,  31,  25],
#         [ 26,  25,  19],
#         [ 26,  25,  19],
# ...

# %%
cv2.imshow('Frame-1', frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps= int(vid.get(cv2.CAP_PROP_FPS))

# %%
width, height, frames, fps
# Out:
# (1270, 720, 1409, 26)

# %%
vid=cv2.VideoCapture('robots.mp4')

# %%
vid
# Out:
# < cv2.VideoCapture 000001B214A38B30>

# %%
width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames = int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps= int(vid.get(cv2.CAP_PROP_FPS))

# %%
width, height, frames, fps
# Out:
# (640, 640, 1799, 30)

# %%
vid = cv2.VideoCapture('robots.mp4')
while True:
    ret, frame = vid.read()
    if not ret:
        break
    #Process the frame(eg. apply filters, detect objects)
    cv2.imshow('Video', frame)
    if cv2.waitKey(5) == ord('q'):
        break
cv2.destroyAllWindows()

# %%
vid = cv2.VideoCapture('nature.mp4')
while True:
    ret, frame = vid.read()
    if not ret:
        break
    #Process the frame(eg. apply filters, detect objects)
    cv2.imshow('Video', frame)
    if cv2.waitKey(5) == ord('q'):
        break
cv2.destroyAllWindows()

# %% [markdown]
# <h4>Extract and save the frames</h4>

# %%
vid = cv2.VideoCapture('nature.mp4')

#get the first frmae and see if successful
success, frame = vid.read()

#initiate count
count = 1
#keep extracting frames as long as success is True
while success:
    cv2.imwrite(f'nature_images/{count}.jpg', frame)
    success, frame = vid.read()
    count += 1

# %% [markdown]
# <h4>Working with timestamp data</h4>

# %%
timestamp = '00:00:35.00'
hours, minutes, seconds = [float(i) for i in timestamp.split(':')]
print(hours, minutes, seconds)
# Out:
# 0.0 0.0 35.0

# %%
timestamp.split(':')
# Out:
# ['00', '00', '35.00']

# %%
trigger_frame= hours*3600*fps + minutes*60*fps + seconds* fps
print(frames, trigger_frame)
# Out:
# 1799 1050.0

# %%
#go to frame selected by timestamp
vid.set(1, trigger_frame)
success, frame = vid.read()

#save the frame into an image file
if success:
    cv2.imwrite('screen.jpg', frame)

# %% [markdown]
# <h4>now with robots</h4>

# %%
vid = cv2.VideoCapture('robots.mp4')

#get the first frmae and see if successful
success, frame = vid.read()

#initiate count
count = 1
#keep extracting frames as long as success is True
while success:
    cv2.imwrite(f'robo_bhai_pics/{count}.jpg', frame)
    success, frame = vid.read()
    count += 1

# %%
timestamp = '00:00:43.00'
hours, minutes, seconds = [float(i) for i in timestamp.split(':')]
print(hours, minutes, seconds)
# Out:
# 0.0 0.0 43.0

# %%
timestamp.split(':')
# Out:
# ['00', '00', '43.00']

# %%
trigger_frame= hours*3600*fps + minutes*60*fps + seconds* fps
print(frames, trigger_frame)
# Out:
# 1799 1290.0

# %%
#go to frame selected by timestamp
vid.set(1, trigger_frame)
success, frame = vid.read()

#save the frame into an image file
if success:
    cv2.imwrite('roboraj.jpg', frame)

# %% [markdown]
# <h4>Capture using camera</h4>

# %%
cap = cv2.VideoCapture(0)

# %%
if cap.isOpened():
    print('camera is present')
else:
    print('no camera is present')
# Out:
# no camera is present

# %%
#read until video is complete
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        #display the resulting frame
        cv2.imshow('Frame', frame)
        #press Q on keyboard to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        else:
            break
#when everything done, release the video capture object
cap.release()

#closes all the frames
cv2.destroyAllWindows()

# %% [markdown]
# <h4>capture and store the object</h4>

# %%
video = cv2.VideoCapture(0)

# %%
frame_width = int(video.get(3))
frame_height = int(video.get(4))
size = (frame_width, frame_height)

# %%
size
# Out:
# (0, 0)

# %%
#Below videowrite

result = cv2.VideoWriter('myvid.avi', cv2.VideoWriter_fourcc(*'MJPG'),
                        30, size)

# %%
while(True):
    ret, frame = video.read()
    if ret == True:
        result.write(frame)
        cv2.imshow('Frame', frame)
        if cv2.waitKey(1) & 0xFF == ord('s'):
            break
    else:
        break
cv2.destroyAllWindows()
video.release()
