# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image1 = cv2.imread('lenna.png')
image2 = cv2.imread('sun.png')

# %%
cv2.imshow('lenna', image1)
cv2.imshow('sun',image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1.shape, image2.shape
# Out:
# ((512, 512, 3), (512, 512, 3))

# %%
###image addd

# %%
added_image = cv2.add(image1,image2)

# %%
cv2.imshow('Addition of ojas', added_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
added_image = image1+image2

# %%
cv2.imshow('Additjuon', added_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
######image sub

# %%
sub_image = cv2.subtract(image1,image2)

# %%
cv2.imshow('subtract of ojas', sub_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
sub_image = image1-image2

# %%
cv2.imshow('subtactnif', sub_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_image = added_image - sub_image

cv2.imshow('navi img', new_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('addde with scaler', image1 -30)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('addde with scaler', image1 -30)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('addde with scaler', image2 -30)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('addde with scaler', image2 +30)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
### IMAGE BLENDING

# %%
alpha  = 0.5
blended_image  = cv2.addWeighted(image1, alpha, image2, 1 - alpha, 0)

cv2.imshow('Blended Image', blended_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
alpha  = 0.2
blended_image  = cv2.addWeighted(image1, alpha, image2, 1 - alpha, 0)

cv2.imshow('Blended Image', blended_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
##divide and multiple the images

# %%
brightened_image = cv2.multiply(image1, 1.5)
darkened_image = cv2.divide(image1, 2.5)

cv2.imshow('brightemned image', brightened_image)
cv2. imshow('original image', image1)
cv2.imshow('dark img', darkened_image)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
img1 = cv2.imread('input1.png')
img2 = cv2.imread('input2.png')

# %%
cv2.imshow('input1', img1)
cv2.imshow('input 2', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1.shape
# Out:
# (250, 499, 3)

# %%
img2.shape
# Out:
# (250, 499, 3)

# %%
anded_image = cv2.bitwise_and(img1, img2)

# %%
cv2.imshow('input1', img1)
cv2.imshow('input 2', img2)
cv2.imshow('and', anded_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1 = cv2.imread('lenna.png')
image2 = cv2.imread('sun.png')


anded_image = cv2.bitwise_and(image1, image2)
cv2.imshow('and', anded_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
### bitwise OR

# %%
ored_image = cv2.bitwise_or(img1, img2)

# %%
cv2.imshow('Input1', img1)
cv2.imshow('Input2', img2)
cv2.imshow('or',ored_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
## bitwise xor

# %%
xored_image = cv2.bitwise_xor(img1, img2)

# %%
cv2.imshow('Input1', img1)
cv2.imshow('Input2', img2)
cv2.imshow('or',xored_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
xored_image = cv2.bitwise_xor(image1, image2)
cv2.imshow('xor',xored_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#####bitwis not

# %%
not_image1 = cv2.bitwise_not(img1)
not_image2 = cv2.bitwise_not(img2)

# %%
cv2.imshow('input1',img1)
cv2.imshow('not', not_image1)

cv2.imshow('input2',img2)
cv2.imshow('not', not_image2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
not_image = cv2.bitwise_not(image1)
cv2.imshow('not', not_image2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#####    image Masking

# %%
img = cv2.imread('rgy.jpg')

# %%
cv2.imshow('fruirts', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
mg = cv2.imread('rgy.jpg')

cv2.imshow('fruits',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# The kernal  to be used for dilation purpose
kernal = np.ones((5,5),np.uint8)

# converting the imagfe to HSV format
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# defining the lower and upper values of HSV, this will detect yellow colour
Lower_hsv = np.array([20, 70, 100])
Upper_hsv = np.array([30, 255, 255])


Mask = cv2.inRange(hsv, Lower_hsv, Upper_hsv)
Mask = cv2.erode(Mask, kernal, iterations = 1)
Mask = cv2.morphologyEx(Mask, cv2.MORPH_OPEN, kernal)
Mask = cv2.dilate(Mask, kernal, iterations = 1)
Mask = cv2.bitwise_not(Mask)
cv2.imshow('My Image',img)
cv2.imshow('Mask', Mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
mask_yellow = cv2.bitwise_not(Mask)
Mask = cv2.bitwise_and(img, img, mask= mask_yellow)

# %%
cv2.imshow('Mask', Mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
####SPLIT THE CHANNEL

# %%
image = cv2.imread('lenna.png')

# %%
image.shape
# Out:
# (512, 512, 3)

# %%
b,g,r= cv2.split(image)

# %%
b.shape
# Out:
# (512, 512)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,3,1)
plt.title('Blue Channel')
plt.imshow(b, cmap = 'gray')

plt.subplot(1,3,2)
plt.title('Green Channel')
plt.imshow(g, cmap = 'gray')

plt.subplot(1,3,3)
plt.title('Red Channel')
plt.imshow(r, cmap = 'gray')

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,3,1)
plt.title('Blue Channel')
plt.imshow(b, cmap = 'Blues')

plt.subplot(1,3,2)
plt.title('Green Channel')
plt.imshow(g, cmap = 'Greens')

plt.subplot(1,3,3)
plt.title('Red Channel')
plt.imshow(r, cmap = 'Reds')

# %%
b
# Out:
# array([[125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 60,  60,  58, ...,  84,  76,  79],
#        [ 57,  57,  62, ...,  79,  81,  81],
#        [ 57,  57,  62, ...,  79,  81,  81]], dtype=uint8)

# %%
bgr= cv2.merge([b,g,r])

# %%
plt.imshow(bgr)

# %%
rgb = cv2.merge([r,g,b])

# %%
plt.imshow(rgb)

# %%
gbr= cv2.merge([g,b,r])
brg= cv2.merge([b,r,g])
rbg= cv2.merge([r,b,g])
grb= cv2.merge([g,r,b])
plt.figure(figsize=(10,5))
plt.subplot(1,5,1)
plt.title('gbr')
plt.imshow(gbr)
plt.subplot(1,5,2)
plt.title('brg')
plt.imshow(brg)
plt.subplot(1,5,3)
plt.title('rbg')
plt.imshow(rbg)
plt.subplot(1,5,4)
plt.title('grb')
plt.imshow(grb)

# %%
new_channel= np.zeros([512,512],dtype=np.uint8)+255

# %%
new_channel
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
new_image= cv2.merge([r,g,new_channel])

# %%
plt.imshow(new_image)

# %%
new_image= cv2.merge([r,new_channel,b])
plt.imshow(new_image)

# %%
img1= cv2.imread('sun.png')

# %%
b1,g1,r1= cv2.split(img1)

# %%
new_image= cv2.merge([r1,b,g])
plt.imshow(new_image)

# %%
##color space

# %%
from PIL import Image

# %%
image = Image.open('lenna.png')

img_cmyk = image.convert('CMYK')

# %%
img_cmyk.mode
# Out:
# 'CMYK'

# %%
image.mode
# Out:
# 'RGB'
