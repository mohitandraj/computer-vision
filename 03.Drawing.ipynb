# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#read the image
image = cv2.imread('lenna.png')

# %% [raw]
# # Define starting & ending points of  the line
# start_point = (100, 50) # (x1, y1)
# end_point = (300, 200)  # (x2, y2)
#
# # Draw  a green line with thickness of 2 pixels
#
# #cv2.line(image, start_point, end_point, (255, 0, 0), 2);
# cv2.line(image, start_point, end_point, (0, 255, 0), 2);
#
# cv2.imshow('Imag with Line', image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# Define starting & ending points of  the line
start_point = (0, 00) # (x1, y1)
end_point = (512, 512)  # (x2, y2)

# Draw  a green line with thickness of 2 pixels

#cv2.line(image, start_point, end_point, (255, 0, 0), 2);
cv2.line(image, start_point, end_point, (0, 0, 255), 2);

cv2.imshow('Imag with Line', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Define starting & ending points of  the line
start_point = (0, 512) # (x1, y1)
end_point = (512, 0)  # (x2, y2)

# Draw  a green line with thickness of 2 pixels

#cv2.line(image, start_point, end_point, (255, 0, 0), 2);
cv2.line(image, start_point, end_point, (0, 0, 255), 2);

cv2.imshow('Imag with Line', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Draw using Equation

# %%
x = np.arange(1, 100, 0.25)

# %%
x
# Out:
# array([ 1.  ,  1.25,  1.5 ,  1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,
#         3.25,  3.5 ,  3.75,  4.  ,  4.25,  4.5 ,  4.75,  5.  ,  5.25,
#         5.5 ,  5.75,  6.  ,  6.25,  6.5 ,  6.75,  7.  ,  7.25,  7.5 ,
#         7.75,  8.  ,  8.25,  8.5 ,  8.75,  9.  ,  9.25,  9.5 ,  9.75,
#        10.  , 10.25, 10.5 , 10.75, 11.  , 11.25, 11.5 , 11.75, 12.  ,
#        12.25, 12.5 , 12.75, 13.  , 13.25, 13.5 , 13.75, 14.  , 14.25,
#        14.5 , 14.75, 15.  , 15.25, 15.5 , 15.75, 16.  , 16.25, 16.5 ,
#        16.75, 17.  , 17.25, 17.5 , 17.75, 18.  , 18.25, 18.5 , 18.75,
#        19.  , 19.25, 19.5 , 19.75, 20.  , 20.25, 20.5 , 20.75, 21.  ,
#        21.25, 21.5 , 21.75, 22.  , 22.25, 22.5 , 22.75, 23.  , 23.25,
#        23.5 , 23.75, 24.  , 24.25, 24.5 , 24.75, 25.  , 25.25, 25.5 ,
#        25.75, 26.  , 26.25, 26.5 , 26.75, 27.  , 27.25, 27.5 , 27.75,
#        28.  , 28.25, 28.5 , 28.75, 29.  , 29.25, 29.5 , 29.75, 30.  ,
#        30.25, 30.5 , 30.75, 31.  , 31.25, 31.5 , 31.75, 32.  , 32.25,
#        32.5 , 32.75, 33.  , 33.25, 33.5 , 33.75, 34.  , 34.25, 34.5 ,
#        34.75, 35.  , 35.25, 35.5 , 35.75, 36.  , 36.25, 36.5 , 36.75,
#        37.  , 37.25, 37.5 , 37.75, 38.  , 38.25, 38.5 , 38.75, 39.  ,
#        39.25, 39.5 , 39.75, 40.  , 40.25, 40.5 , 40.75, 41.  , 41.25,
#        521.5288, 523.4788, 525.4288, 527.3788, 529.3288, 531.2788,
#        533.2288, 535.1788, 537.1288, 539.0788, 541.0288, 542.9788,
#        544.9288, 546.8788, 548.8288, 550.7788, 552.7288, 554.6788,
#        556.6288, 558.5788, 560.5288, 562.4788, 564.4288, 566.3788,
#        568.3288, 570.2788, 572.2288, 574.1788, 576.1288, 578.0788,
#        580.0288, 581.9788, 583.9288, 585.8788, 587.8288, 589.7788,
#        591.7288, 593.6788, 595.6288, 597.5788, 599.5288, 601.4788,
#        603.4288, 605.3788, 607.3288, 609.2788, 611.2288, 613.1788,
#        615.1288, 617.0788, 619.0288, 620.9788, 622.9288, 624.8788,
#        626.8288, 628.7788, 630.7288, 632.6788, 634.6288, 636.5788,
#        638.5288, 640.4788, 642.4288, 644.3788, 646.3288, 648.2788,
#        650.2288, 652.1788, 654.1288, 656.0788, 658.0288, 659.9788,
#        661.9288, 663.8788, 665.8288, 667.7788, 669.7288, 671.6788,
#        673.6288, 675.5788, 677.5288, 679.4788, 681.4288, 683.3788,
#        685.3288, 687.2788, 689.2288, 691.1788, 693.1288, 695.0788,
#        697.0288, 698.9788, 700.9288, 702.8788, 704.8288, 706.7788,
#        708.7288, 710.6788, 712.6288, 714.5788, 716.5288, 718.4788,
#        720.4288, 722.3788, 724.3288, 726.2788, 728.2288, 730.1788,
#        732.1288, 734.0788, 736.0288, 737.9788, 739.9288, 741.8788,
#        743.8288, 745.7788, 747.7288, 749.6788, 751.6288, 753.5788,
#        755.5288, 757.4788, 759.4288, 761.3788, 763.3288, 765.2788,
#        767.2288, 769.1788, 771.1288, 773.0788, 775.0288, 776.9788,
#        778.9288, 780.8788, 782.8288, 784.7788, 786.7288, 788.6788,
#        790.6288, 792.5788, 794.5288, 796.4788, 798.4288, 800.3788,
#        802.3288, 804.2788, 806.2288, 808.1788, 810.1288, 812.0788])

# %%
plt.scatter(x, y, marker = '.')
plt.plot(x, y, color='orange')

# %% [markdown]
# ### Drawing a 3D line

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Define Start and end points of the line in 3D space
start_point = (10, 22, 33)
end_point = (44, 52, 67)

# Create a 3D Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the Line
ax.plot([start_point[0], end_point[0]],
        [start_point[0], end_point[0]],
        [start_point[0], end_point[0]], 'r-')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Line')

# Show the plot
plt.show()

# %% [markdown]
# ### Line Using Turtle

# %%
# import turtle

# # Create a turtle object
# t = turtle.Turtle()

# # Set the line width (Optional)
# t.pensize(1)

# # Move the Turtle to the Starting position
# t.penup()
# t.goto(0, -50) # Replace with your desired starting coordinates (x, y)
# t.pendown()

# # Move the turtle to the ending position (drawing the line)
# t.goto(300, 0) # Replace with your desired ending coordinates (x, y)

# # Kepp the window open until closed manually
# turtle.done()

# %% [markdown]
# ### Rectangle Drawing

# %%
# Load your Image
image = cv2.imread('lenna.png')

# Define top-left corner & dimensions
x, y, w, h = 100, 50, 200, 150

# Draw a blue rectangle with thickness of 2 pixels
cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 10)

# Show the Rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load your Image
image = cv2.imread('lenna.png')

# Define top-left corner & dimensions
x, y, w, h = 0, 0, 512, 512

# Draw a blue rectangle with thickness of 2 pixels
cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 255), 10)

# Show the Rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load your Image
image = cv2.imread('lenna.png')

# Define top-left corner & dimensions
x, y, w, h = 0, 0, 256, 256
 
# Draw a blue rectangle with thickness of 2 pixels


cv2.rectangle(image, (0,0), (255,255), (255, 255, 0), 10)
cv2.rectangle(image, (0,255), (255,511), (0,255, 255), 10)
cv2.rectangle(image, (256,256), (511,511), (0, 0, 255), 10)
cv2.rectangle(image, (256,0), (511,256), (0, 255, 0), 10)

# Show the Rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = np.ones([200,300]) - 0.25
cv2.rectangle(image, (50, 50), (250, 150), (0, 140, 0), 10)
cv2.imshow('Sample Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
x_min, y_min, x_max, y_max = 1,2,4,7
rectangle= plt.Rectangle((x_min,y_min),x_max-x_min,y_max-y_min,color='red',alpha=0.1)

plt.plot([x_min,x_max],[y_min,y_max],'b-',label='X-axis')
plt.plot([x_min,x_min],[y_min,y_max],'g-',label='Y-axis')
plt.gca().add_patch(rectangle)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("rectangular plot")
plt.legend()
plt.show()

# %%
import turtle
t= turtle.Turtle()
t.color("green")
t.pensize(5)
t.speed(0)
t.penup()
t.goto(-50,25)
t.pendown()
t.forward(100)
t.left(90)
t.forward(50)
t.left(90)
t.forward(100)
t.left(90)
t.forward(50)
t.hideturtle()

turtle.done()

# %%
image =cv2.imread('lenna.png')

center= (150,100)
axes = (100,50)
angle = 45

cv2.ellipse(image,center,axes,angle,0,360,(0,255,0),3)
cv2.ellipse(image,(200,400),axes,0,0,360,(0,255,0),3)
cv2.imshow("image with ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image =cv2.imread('lenna.png')

center= (256,256)
axes = (256,150)
angle = 90

cv2.ellipse(image,center,axes,angle,0,360,(0,255,0),3)
cv2.imshow("image with ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image =cv2.imread('lenna.png')

center= (256,256)
axes = (150,255)
angle = 0

cv2.ellipse(image,center,axes,angle,180,360,(255,0,0),15)
cv2.ellipse(image,center,axes,angle,0,180,(0,0,256),15)
cv2.imshow("image with ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
center= (0,0)
width=8
height=5
angle =45

ellipse= Ellipse(xy=center, width=width, height=height, angle=angle, color='blue')

fig, ax = plt.subplots()
ax.add_patch(ellipse)
ax.set_aspect('equal')

ax.set_xlim(-width -width/5, width+width/5)
ax.set_ylim(-height -height/5, height+height/5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('ellipse plot')

plt.show()

# %%
import cv2

image = cv2.imread('lenna.png')

center = (256, 256)  
radius = 150         

# Draw the circle
cv2.ellipse(image, center, (radius, radius), 0, 0, 360, (255, 0, 0), 15)

cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

image = cv2.imread('lenna.png')

center = (256, 256)  
radius = 150         

cv2.circle(image, center,radius, (0, 255, 200), 15)

cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

image = cv2.imread('lenna.png')

center = (256, 256)  
for i in range(10,400, 5): 
    cv2.circle(image, center, i,  (0, i//2, i), 2)

cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
## using matplotlib

# %%
center= (0,0)
radius= 5

circle = plt.Circle(xy=center, radius= radius, color='orange')

fig,ax= plt.subplots()
ax.add_patch(circle)
ax.set_aspect('equal')
 
ax.set_xlim(-radius -radius/5, radius + radius/5)
ax.set_ylim(-radius -radius/5, radius + radius/5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('circle plot')

plt.show()

# %%
## CANVAS

# %%
from tkinter import *

# %%
top = Tk() #create the object of UI window
top.title('my application')
top.geometry('400x300')

top.mainloop() #keep it running indefinitely

# %%
top = Tk() #create the object of UI window
top.title('my application')
top.geometry('400x300')
 
Label(text="Enter your name").pack()
Entry(top).pack()
Button(top, text='click here').pack()

top.mainloop() #keep it running indefinitely

# %%
top = Tk() #create the object of UI window
top.title('my application')
top.geometry('400x300')

def show():
    name= e.get()
    print('Welcome',name)
 
l= Label(text="Enter your name").pack()
e= Entry(top).pack()
b= Button(top, text='click here', command=show).pack()


top.mainloop() #keep it running indefinitely

# %%
# top = Tk() #create the object of UI window
top.title('my application')
top.geometry('400x300')

def show():
    name= int(e.get())
    print('square is:',name**2)
Label(text="Enter your name").pack()
Entry(top).pack()
Button(top, text='find square', command=show).pack()


top.mainloop() #keep it running indefinitely

# %%
top = Tk() #create the object of UI window
top.title('my application')
top.geometry('400x300')

def show():
    num= int(e.get())
    result.config(text= 'square is:' + str(num**2))
 
Label(text="Enter your name").pack()
e= Entry(top)
e.pack()
Button(top, text='click here', command=show).pack()
result= Label('Square is:')
result.pack()


top.mainloop() #keep it running indefinitely
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[158], line 13
#      11 e.pack()
#      12 Button(top, text='click here', command=show).pack()
# ---> 13 result= Label('Square is:')
#      14 result.pack()
#      17 top.mainloop() #keep it running indefinitely
#
# File ~\AppData\Local\anaconda3\Lib\tkinter\__init__.py:3248, in Label.__init__(self, master, cnf, **kw)
#    3230 def __init__(self, master=None, cnf={}, **kw):
#    3231     """Construct a label widget with the parent MASTER.
#    3232
#    3233     STANDARD OPTIONS
#    (...)
#    3246
#    3247     """
# -> 3248     Widget.__init__(self, master, 'label', cnf, kw)
#
# File ~\AppData\Local\anaconda3\Lib\tkinter\__init__.py:2653, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2651     cnf = _cnfmerge((cnf, kw))
#    2652 self.widgetName = widgetName
# -> 2653 self._setup(master, cnf)
#    2654 if self._tclCommands is None:
#    2655     self._tclCommands = []
#
# File ~\AppData\Local\anaconda3\Lib\tkinter\__init__.py:2622, in BaseWidget._setup(self, master, cnf)
#    2620     master = _get_default_root()
#    2621 self.master = master
# -> 2622 self.tk = master.tk
#    2623 name = None
#    2624 if 'name' in cnf:
#
# AttributeError: 'str' object has no attribute 'tk'
