# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img= cv2.imread('lenna.png')
img= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
binary_image = img>127

# %%
binary_image
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.imshow(binary_image, cmap= 'gray')

# %%
ret, thresh1 = cv2.threshold(img,120,255,cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img,120,255,cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img,120,255,cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img,120,255,cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img,120,255,cv2.THRESH_TOZERO_INV)

plt.figure(figsize=(15,10))
plt.subplot(151)
plt.title('Binary Thresholding')
plt.imshow(thresh1,cmap='gray')
plt.subplot(152)
plt.title('Inverse Binary Thresholding')
plt.imshow(thresh2,cmap='gray')
plt.subplot(153)
plt.title('Truncation Thresholding')
plt.imshow(thresh3,cmap='gray')
plt.subplot(154)
plt.title('Tozero Thresholding')
plt.imshow(thresh4,cmap='gray')
plt.subplot(155)
plt.title('Inverse Tozero Thresholding')
plt.imshow(thresh5,cmap='gray')

# %%
##exercise
#open image sun.png , create mirrir image of this horizonally,
#rescale it by 1.5 times, create binary image of it by threshold 115
#show and save the image

# %%
original_image= cv2.imread('sun.png')

# %%
mirrored_image = cv2.flip(original_image, 1)

# %%
height, width = mirrored_image.shape[:2]
rescaled_image = cv2.resize(mirrored_image, (int(width * 1.5), int(height * 1.5)))

# %%
grayscale_image = cv2.cvtColor(rescaled_image, cv2.COLOR_BGR2GRAY)  
_, binary_image = cv2.threshold(grayscale_image, 115, 255, cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(12, 8))

plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
plt.axis("off")

plt.subplot(1, 3, 2)
plt.title("Mirrored & Rescaled")
plt.imshow(cv2.cvtColor(rescaled_image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
plt.axis("off")

plt.subplot(1, 3, 3)
plt.title("Binary Image")
plt.imshow(binary_image, cmap='gray')
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
cv2.imwrite('sun_binary.png', binary_image)
# Out:
# True

# %%
# img_mirror=cv2.flip(img,1)
# img_scale= cv2.resize(img,None,fx=1.5,fy=1.5)
# img_gray=cv2.cvtColor(img_scale,cv2.COLOR_BGR2GRAY)
# ret, img_thresh= cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY)
# plt.imshow(img_thresh,cmap='gray')
# cv2.imwrite('binary_image.jpg',img_thresh)

# %%
img = cv2.imread('lenna.png')

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_, thresh_otsu = cv2.threshold(gray,120,255,cv2.THRESH_OTSU)

cv2.imshow('Original Image', img)
cv2.imshow('Otsu Thresholding', thresh_otsu)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from skimage import io, filters
image = io.imread('lenna.png', as_gray = True)

# %%
threshold = filters.threshold_otsu(image)
binary_image = image > threshold

# %%
threshold
# Out:
# 0.43353890701593134

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10,5))

ax1.imshow(image, cmap = 'gray')
ax1.set_title('Original grayscale image')

ax2.imshow(binary_image, cmap = 'gray')
ax2.set_title("Binary image after Otsu's thresholding")

plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (10,5))

ax1.imshow(image, cmap = 'gray')
ax1.set_title('Original grayscale image')

ax2.imshow(binary_image, cmap = 'gray')
ax2.set_title("Binary image after Otsu's thresholding")

ax3.imshow(thresh1,cmap='gray')
ax3.set_title("binary thresholding")

plt.show()
